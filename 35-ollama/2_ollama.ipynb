# %%
# !pip install ollama

# %%
import ollama

# %%
response=ollama.generate(model="gemma3:1b",prompt="why sky is blue")

print(response.response)
# Out:
# Okay, let's break down why the sky is blue! It's a surprisingly complex phenomenon, but the main reason boils down to a phenomenon called **Rayleigh scattering**. Here's a breakdown of the explanation:
#
# **1. Sunlight Contains All Colors:**
#
# *  Sunlight appears white, but it's actually made up of all the colors of the rainbow – red, orange, yellow, green, blue, indigo, and violet. Think of a prism splitting sunlight into its components.
#
# **2. Entering the Earth's Atmosphere:**
#
# * When sunlight enters the Earth's atmosphere, it bumps into tiny air molecules (mostly nitrogen and oxygen).
#
# **3. Rayleigh Scattering – The Key Process:**
#
# * **Rayleigh scattering** is the phenomenon where light waves are scattered by particles much smaller than the wavelength of light. This is the crucial part.
# ...

# %%
response=ollama.generate(model="qwen3.5",prompt="who is modi",stream=True)

for i in response:
  print(i["response"],end="")
